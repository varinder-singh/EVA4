# %%
from google.colab import drive
drive.mount('/content/drive')
# Change Directory on Gdrive
# %cd /content/drive/My \Drive/Colab \Notebooks/EVA4/S11-Assignment-Solution/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab Notebooks/EVA4/S11-Assignment-Solution

# %%
import dataloader
from albumentationsTransformations import AlbumentationsTransforms
transforms = AlbumentationsTransforms()
trainloader,testloader=dataloader.loadCiFAR10(transforms)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Is CUDA available:  True

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision.models.resnet import ResNet, BasicBlock
from model import ResNetA11 as resnetA11


from torchsummary import summary
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
mymodel = resnetA11.ResNetA11().to(device)
summary(mymodel, input_size=(3, 32, 32))
# Out:
# cuda
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#             Conv2d-4          [-1, 128, 32, 32]          73,728
#          MaxPool2d-5          [-1, 128, 16, 16]               0
#        BatchNorm2d-6          [-1, 128, 16, 16]             256
#               ReLU-7          [-1, 128, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]         147,456
#        BatchNorm2d-9          [-1, 128, 16, 16]             256
#            Conv2d-10          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-11          [-1, 128, 16, 16]             256
#          ResBlock-12          [-1, 128, 16, 16]               0
#            Conv2d-13          [-1, 256, 16, 16]         294,912
#         MaxPool2d-14            [-1, 256, 8, 8]               0
#       BatchNorm2d-15            [-1, 256, 8, 8]             512
#              ReLU-16            [-1, 256, 8, 8]               0
#          ResBlock-17            [-1, 256, 8, 8]               0
#            Conv2d-18            [-1, 512, 8, 8]       1,179,648
#         MaxPool2d-19            [-1, 512, 4, 4]               0
#       BatchNorm2d-20            [-1, 512, 4, 4]           1,024
#              ReLU-21            [-1, 512, 4, 4]               0
#            Conv2d-22            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-23            [-1, 512, 4, 4]           1,024
#            Conv2d-24            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-25            [-1, 512, 4, 4]           1,024
#          ResBlock-26            [-1, 512, 4, 4]               0
#         MaxPool2d-27            [-1, 512, 1, 1]               0
#            Linear-28                   [-1, 10]           5,130
# ================================================================
# Total params: 6,573,130
# Trainable params: 6,573,130
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 6.25
# Params size (MB): 25.07
# Estimated Total Size (MB): 31.34
# ----------------------------------------------------------------

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import OneCycleLR

optimizer = optim.SGD(mymodel.parameters(), lr=0.001, momentum=0.9, weight_decay=0.0003)

# Setup One Cycle LR
scheduler = OneCycleLR(optimizer, max_lr=0.015, steps_per_epoch=49,pct_start=0.2, div_factor=10, final_div_factor=10, epochs=98, last_epoch=-1)

# %%
from traintest import train, test 
EPOCHS = 40
for epoch in range(EPOCHS):  # loop over the dataset multiple times
    print("EPOCH: ", epoch)
    train.train(mymodel, device, trainloader, epoch, optimizer, scheduler, 'l1')
    #Save the model for future use.
    torch.save({'epoch':epoch,
                'model_state_dict': mymodel.state_dict(),
               'optimizer_state_dict': optimizer.state_dict()
               }, 'training_a11.pt')
    test.test(mymodel, device, testloader, 'l1')
# Out:
#   0%|          | 0/98 [00:00<?, ?it/s]
# Finished Training
# EPOCH:  0
# Loss=1.642771601676941 Batch_id=97 Accuracy=32.75: 100%|██████████| 98/98 [00:29<00:00,  3.32it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 14404.291870117188, Accuracy: 4787/10000 (47.87%)
#
# EPOCH:  1
# Loss=1.3140538930892944 Batch_id=97 Accuracy=49.93: 100%|██████████| 98/98 [00:29<00:00,  3.29it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 11969.110931396484, Accuracy: 5726/10000 (57.26%)
#
# EPOCH:  2
# Loss=1.0803217887878418 Batch_id=97 Accuracy=56.85: 100%|██████████| 98/98 [00:29<00:00,  3.32it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 10951.113952636719, Accuracy: 6148/10000 (61.48%)
#
# EPOCH:  3
# Loss=1.0350706577301025 Batch_id=97 Accuracy=62.30: 100%|██████████| 98/98 [00:30<00:00,  3.21it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 10929.471954345703, Accuracy: 6281/10000 (62.81%)
#
# EPOCH:  4
# Loss=1.0119884014129639 Batch_id=97 Accuracy=66.08: 100%|██████████| 98/98 [00:30<00:00,  3.17it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 7378.559509277344, Accuracy: 7443/10000 (74.43%)
#
# EPOCH:  5
# Loss=0.831506609916687 Batch_id=97 Accuracy=69.22: 100%|██████████| 98/98 [00:30<00:00,  3.22it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 8032.771453857422, Accuracy: 7179/10000 (71.79%)
#
# EPOCH:  6
# Loss=0.7751888036727905 Batch_id=97 Accuracy=72.59: 100%|██████████| 98/98 [00:29<00:00,  3.28it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 6481.848571777344, Accuracy: 7756/10000 (77.56%)
#
# EPOCH:  7
# Loss=0.6073294878005981 Batch_id=97 Accuracy=74.04: 100%|██████████| 98/98 [00:29<00:00,  3.29it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 6938.468338012695, Accuracy: 7655/10000 (76.55%)
#
# EPOCH:  8
# Loss=0.6729326844215393 Batch_id=97 Accuracy=76.54: 100%|██████████| 98/98 [00:30<00:00,  3.26it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 6306.571380615234, Accuracy: 7843/10000 (78.43%)
#
# EPOCH:  9
# Loss=0.5747169256210327 Batch_id=97 Accuracy=78.00: 100%|██████████| 98/98 [00:30<00:00,  3.17it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 5456.197463989258, Accuracy: 8133/10000 (81.33%)
#
# EPOCH:  10
# Loss=0.5387391448020935 Batch_id=97 Accuracy=79.02: 100%|██████████| 98/98 [00:31<00:00,  3.15it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 5560.06120300293, Accuracy: 8151/10000 (81.51%)
#
# EPOCH:  11
# Loss=0.570037841796875 Batch_id=97 Accuracy=80.35: 100%|██████████| 98/98 [00:30<00:00,  3.20it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 6495.11051940918, Accuracy: 7877/10000 (78.77%)
#
# EPOCH:  12
# Loss=0.6257877349853516 Batch_id=97 Accuracy=81.79: 100%|██████████| 98/98 [00:30<00:00,  3.22it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 4830.054069519043, Accuracy: 8334/10000 (83.34%)
#
# EPOCH:  13
# Loss=0.44497495889663696 Batch_id=97 Accuracy=82.05: 100%|██████████| 98/98 [00:29<00:00,  3.28it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 4584.427200317383, Accuracy: 8436/10000 (84.36%)
#
# EPOCH:  14
# Loss=0.46881118416786194 Batch_id=97 Accuracy=82.86: 100%|██████████| 98/98 [00:30<00:00,  3.22it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 4627.921615600586, Accuracy: 8482/10000 (84.82%)
#
# EPOCH:  15
# Loss=0.37511563301086426 Batch_id=97 Accuracy=83.90: 100%|██████████| 98/98 [00:29<00:00,  3.30it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 4279.587448120117, Accuracy: 8590/10000 (85.90%)
#
# EPOCH:  16
# Loss=0.46692466735839844 Batch_id=97 Accuracy=85.03: 100%|██████████| 98/98 [00:29<00:00,  3.30it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 4331.747894287109, Accuracy: 8532/10000 (85.32%)
#
# EPOCH:  17
# Loss=0.3536638617515564 Batch_id=97 Accuracy=84.99: 100%|██████████| 98/98 [00:29<00:00,  3.28it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 4243.078109741211, Accuracy: 8607/10000 (86.07%)
#
# EPOCH:  18
# Loss=0.40415331721305847 Batch_id=97 Accuracy=85.88: 100%|██████████| 98/98 [00:29<00:00,  3.33it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 4200.280685424805, Accuracy: 8593/10000 (85.93%)
#
# EPOCH:  19
# Loss=0.49917522072792053 Batch_id=97 Accuracy=86.64: 100%|██████████| 98/98 [00:29<00:00,  3.34it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 4227.139175415039, Accuracy: 8614/10000 (86.14%)
#
# EPOCH:  20
# Loss=0.40156540274620056 Batch_id=97 Accuracy=86.93: 100%|██████████| 98/98 [00:29<00:00,  3.36it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 3850.0023651123047, Accuracy: 8739/10000 (87.39%)
#
# EPOCH:  21
# Loss=0.2938728928565979 Batch_id=97 Accuracy=87.42: 100%|██████████| 98/98 [00:29<00:00,  3.37it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 3967.5473861694336, Accuracy: 8723/10000 (87.23%)
#
# EPOCH:  22
# Loss=0.35576725006103516 Batch_id=97 Accuracy=88.10: 100%|██████████| 98/98 [00:29<00:00,  3.32it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 3717.4666748046875, Accuracy: 8795/10000 (87.95%)
#
# EPOCH:  23
# Loss=0.36985692381858826 Batch_id=97 Accuracy=88.75: 100%|██████████| 98/98 [00:29<00:00,  3.36it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 3834.722198486328, Accuracy: 8756/10000 (87.56%)
#
# EPOCH:  24
# Loss=0.22361214458942413 Batch_id=97 Accuracy=89.32: 100%|██████████| 98/98 [00:29<00:00,  3.31it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 3881.6332092285156, Accuracy: 8752/10000 (87.52%)
#
# EPOCH:  25
# Loss=0.35463738441467285 Batch_id=97 Accuracy=89.33: 100%|██████████| 98/98 [00:29<00:00,  3.35it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 3705.6240997314453, Accuracy: 8834/10000 (88.34%)
#
# EPOCH:  26
# Loss=0.2820074260234833 Batch_id=97 Accuracy=89.68: 100%|██████████| 98/98 [00:29<00:00,  3.37it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 3459.551986694336, Accuracy: 8870/10000 (88.70%)
#
# EPOCH:  27
# Loss=0.3430324196815491 Batch_id=97 Accuracy=90.38: 100%|██████████| 98/98 [00:29<00:00,  3.36it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 3429.69669342041, Accuracy: 8878/10000 (88.78%)
#
# EPOCH:  28
# Loss=0.2519267499446869 Batch_id=97 Accuracy=90.86: 100%|██████████| 98/98 [00:28<00:00,  3.41it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 3524.554714202881, Accuracy: 8860/10000 (88.60%)
#
# EPOCH:  29
# Loss=0.30471640825271606 Batch_id=97 Accuracy=90.87: 100%|██████████| 98/98 [00:29<00:00,  3.34it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 3460.4617767333984, Accuracy: 8881/10000 (88.81%)
#
# EPOCH:  30
# Loss=0.28838077187538147 Batch_id=97 Accuracy=91.93: 100%|██████████| 98/98 [00:28<00:00,  3.40it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 3381.2927322387695, Accuracy: 8892/10000 (88.92%)
#
# EPOCH:  31
# Loss=0.2872208058834076 Batch_id=97 Accuracy=91.20: 100%|██████████| 98/98 [00:28<00:00,  3.42it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 3367.4481811523438, Accuracy: 8920/10000 (89.20%)
#
# EPOCH:  32
# Loss=0.21293869614601135 Batch_id=97 Accuracy=92.06: 100%|██████████| 98/98 [00:28<00:00,  3.38it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 3324.2953720092773, Accuracy: 8940/10000 (89.40%)
#
# EPOCH:  33
# Loss=0.14545699954032898 Batch_id=97 Accuracy=92.42: 100%|██████████| 98/98 [00:29<00:00,  3.37it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 3178.51180267334, Accuracy: 8994/10000 (89.94%)
#
# EPOCH:  34
# Loss=0.24686047434806824 Batch_id=97 Accuracy=92.72: 100%|██████████| 98/98 [00:28<00:00,  3.41it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 3146.0379791259766, Accuracy: 9005/10000 (90.05%)
#
# EPOCH:  35
# Loss=0.23340749740600586 Batch_id=97 Accuracy=92.98: 100%|██████████| 98/98 [00:28<00:00,  3.41it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 3210.1372146606445, Accuracy: 8966/10000 (89.66%)
#
# EPOCH:  36
# Loss=0.18152059614658356 Batch_id=97 Accuracy=93.45: 100%|██████████| 98/98 [00:28<00:00,  3.40it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 3252.093215942383, Accuracy: 8964/10000 (89.64%)
#
# EPOCH:  37
# Loss=0.17107336223125458 Batch_id=97 Accuracy=93.63: 100%|██████████| 98/98 [00:28<00:00,  3.38it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 3121.673122406006, Accuracy: 9004/10000 (90.04%)
#
# EPOCH:  38
# Loss=0.11915937811136246 Batch_id=97 Accuracy=94.12: 100%|██████████| 98/98 [00:28<00:00,  3.43it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test Set: Average loss: 3031.1351470947266, Accuracy: 9024/10000 (90.24%)
#
# EPOCH:  39
# Loss=0.2114105373620987 Batch_id=59 Accuracy=94.44:  61%|██████    | 60/98 [00:17<00:10,  3.76it/s]
