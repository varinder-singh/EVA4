# %% [markdown]
# # Image File Path Printer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Change Directory on Gdrive
# %cd /content/drive/My \Drive/Colab \Notebooks/EVA4/S13-Assignment-Solution/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab Notebooks/EVA4/S13-Assignment-Solution

# %%
# !ls
# Out:
# S13-YoloV3-Custom.ipynb  YoloV3-master	YoloV3-master-v1.zip  YoloV3-master.zip

# %%
#! unzip YoloV3-master.zip

# %%
! pwd

# %cd YoloV3-master/

! ls
# Out:
# /content/drive/My Drive/Colab Notebooks/EVA4/S13-Assignment-Solution
# /content/drive/My Drive/Colab Notebooks/EVA4/S13-Assignment-Solution/YoloV3-master
#  annotation_tool   models.py	  results.txt	     train.py
#  cfg		   output	  runs		    'ubdivisions=1'
#  data		   __pycache__	  test_batch0.png    utils
#  detect.py	   README.md	  test.py	     vim.exe.stackdump
#  EVA-Misc	   results.json   ting		     weights
#  frames		   results.png	  train_batch0.png

# %%
#!python train.py --data data/smalcoco/smalcoco.data --batch 10 --cache --epochs 25 --nosave

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg data/cfg/yolov3-custom.cfg --epochs 160 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='data/cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=160, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-04-26 08:52:34.851322: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25949e+07 parameters, 6.25949e+07 gradients
# Caching labels (421 found, 0 missing, 0 empty, 0 duplicate, for 421 images): 100% 421/421 [04:45<00:00,  1.47it/s]
# Caching images (0.2GB): 100% 421/421 [05:12<00:00,  1.35it/s]
# ...

# %%
! ls
# Out:
#  annotation_tool   models.py	  results.txt	     train.py
#  cfg		   output	  runs		    'ubdivisions=1'
#  data		   __pycache__	  test_batch0.png    utils
#  detect.py	   README.md	  test.py	     vim.exe.stackdump
#  EVA-Misc	   results.json   ting		     weights
#  frames		   results.png	  train_batch0.png

# %%
# %cd YoloV3-master/
# Out:
# [Errno 2] No such file or directory: 'YoloV3-master/'
# /content/drive/My Drive/Colab Notebooks/EVA4/S13-Assignment-Solution/YoloV3-master

# %%
# !python detect.py --conf-thres 0.3 --output output --source EVA-Misc/ --cfg data/cfg/yolov3-custom.cfg
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='data/cfg/yolov3-custom.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='output', save_txt=False, source='EVA-Misc/', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25949e+07 parameters, 6.25949e+07 gradients
# image 1/3628 EVA-Misc/image-001.jpg: 320x512 Done. (0.035s)
# image 2/3628 EVA-Misc/image-002.jpg: 320x512 Done. (0.033s)
# image 3/3628 EVA-Misc/image-003.jpg: 320x512 Done. (0.033s)
# image 4/3628 EVA-Misc/image-004.jpg: 320x512 Done. (0.033s)
# image 5/3628 EVA-Misc/image-005.jpg: 320x512 Done. (0.033s)
# image 6/3628 EVA-Misc/image-006.jpg: 320x512 Done. (0.033s)
# image 7/3628 EVA-Misc/image-007.jpg: 320x512 Done. (0.033s)
# image 8/3628 EVA-Misc/image-008.jpg: 320x512 Done. (0.033s)
# ...
